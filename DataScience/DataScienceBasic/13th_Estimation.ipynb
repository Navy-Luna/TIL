# %% [markdown]
# # Lecture 13의 데모
#
# ### Lecture 13의 데모에 대한 코드
#
# 참고자료:
#
# https://github.com/data-8/materials-sp22/blob/main/lec/lec23.ipynb

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')

# %cd /content/gdrive/MyDrive/ITEC419-fa22/lec
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/ITEC419-fa22/lec

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## **Percentiles**

# %%
# Manually compute the 55th percentile
x = make_array(43, 20, 51, 7, 28, 34)

# %%
# Step 1. Sort the data
np.sort(x)
# Out:
# array([ 7, 20, 28, 34, 43, 51])

# %%
# Step 2. Figure out where 55th percentile would be.
# Discrete한 values는 이런식으로 표현해볼 수도 있다.
np.arange(1,7) / len(x) * 100
# Out:
# array([  16.66666667,   33.33333333,   50.        ,   66.66666667,
#          83.33333333,  100.        ])

# %%
np.sort(x).item(3)
# Out:
# 34

# %%
# Alternatively: One line of code
# x가 정렬되어있지 않아도 찾아줌
percentile(55, x)
# Out:
# array([43, 20, 51,  7, 28, 34])

# %%
# Discussion question
s = make_array(1, 5, 7, 3, 9)
np.sort(s)
# Out:
# array([1, 3, 5, 7, 9])

# %%
t = Table().with_column('Percentile', np.arange(0, 101))
t = t.with_column('s', percentile(np.arange(0,101), s))
t.scatter('Percentile')
plots.xticks(np.floor(np.arange(0, len(s)+1) / len(s) * 100))
plots.yticks(np.sort(s))
# Out:
# ([<matplotlib.axis.YTick at 0x7f9cdf975050>,
#   <matplotlib.axis.YTick at 0x7f9cdf953950>,
#   <matplotlib.axis.YTick at 0x7f9ce02531d0>,
#   <matplotlib.axis.YTick at 0x7f9cdf912110>,
#   <matplotlib.axis.YTick at 0x7f9cdf912ad0>],
#  <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# ## **Total Compensation in Population**

# %%
sf = Table.read_table('san_francisco_2019.csv')
sf.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Organization Group</th> <th>Department</th> <th>Job Family</th> <th>Job</th> <th>Salary</th> <th>Overtime</th> <th>Benefits</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Trainer-Journey        </td> <td>91332 </td> <td>0       </td> <td>40059   </td> <td>131391            </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Engineer-Assistant     </td> <td>123241</td> <td>0       </td> <td>49279   </td> <td>172520            </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Business Analyst-Senior</td> <td>115715</td> <td>0       </td> <td>46752   </td> <td>162468            </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (44522 rows omitted)</p>

# %%
# Who made the most money
sf.sort('Total Compensation', descending=True).show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Organization Group</th> <th>Department</th> <th>Job Family</th> <th>Job</th> <th>Salary</th> <th>Overtime</th> <th>Benefits</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>General Administration & Finance</td> <td>Retirement Services</td> <td>Administrative & Mgmt (Unrep)</td> <td>Chief Investment Officer</td> <td>577633</td> <td>0       </td> <td>146398  </td> <td>724031            </td>
#         </tr>
#         <tr>
#             <td>General Administration & Finance</td> <td>Retirement Services</td> <td>Unassigned                   </td> <td>Managing Director       </td> <td>483072</td> <td>0       </td> <td>134879  </td> <td>617951            </td>
#         </tr>
#         <tr>
#             <td>General Administration & Finance</td> <td>Retirement Services</td> <td>Unassigned                   </td> <td>Managing Director       </td> <td>482649</td> <td>0       </td> <td>134905  </td> <td>617554            </td>
#         </tr>
#         <tr>
#             <td>General Administration & Finance</td> <td>Retirement Services</td> <td>Unassigned                   </td> <td>Managing Director       </td> <td>451507</td> <td>0       </td> <td>120276  </td> <td>571784            </td>
#         </tr>
#         <tr>
#             <td>General Administration & Finance</td> <td>Retirement Services</td> <td>Unassigned                   </td> <td>Managing Director       </td> <td>449378</td> <td>0       </td> <td>120857  </td> <td>570235            </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (44520 rows omitted)</p>

# %%
# Who made the least money
sf.sort('Total Compensation', descending=False).show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Organization Group</th> <th>Department</th> <th>Job Family</th> <th>Job</th> <th>Salary</th> <th>Overtime</th> <th>Benefits</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Probation & Parole           </td> <td>Deputy Probation Officer     </td> <td>0     </td> <td>0       </td> <td>0       </td> <td>0                 </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Fire Department</td> <td>Clerical, Secretarial & Steno</td> <td>Senior Clerk Typist          </td> <td>0     </td> <td>0       </td> <td>0       </td> <td>0                 </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Juvenile Court </td> <td>Correction & Detention       </td> <td>Counselor, Juvenile Hall PERS</td> <td>0     </td> <td>0       </td> <td>0       </td> <td>0                 </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Police         </td> <td>Clerical, Secretarial & Steno</td> <td>Clerk Typist                 </td> <td>0     </td> <td>0       </td> <td>0       </td> <td>0                 </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Sheriff        </td> <td>Correction & Detention       </td> <td>Deputy Sheriff               </td> <td>0     </td> <td>0       </td> <td>0       </td> <td>0                 </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (44520 rows omitted)</p>

# %%
# $15/hr, 20 hr/wk, 50 weeks

min_salary = 15 * 20 * 50
sf = sf.where('Salary', are.above(min_salary))

# %%
sf.num_rows
# Out:
# 37103

# %%
sf_bins = np.arange(0, 726000, 25000)
sf.hist('Total Compensation', bins=sf_bins)

# %% [markdown]
# ## **Parameter: Median Total Compensation**

# %%
# 실제 전체 Population에서의 중간값
pop_median = percentile(50, sf.column('Total Compensation'))
pop_median
# Out:
# 135747.0

# %% [markdown]
# ## **Estimating the Parameter (Pretend it is Unknown)**

# %%
# 400개의 sample만 추출하여 중간값을 구해볼 것임 - 뽑을때마다 달라질 것임
# 비복원 추출!
sample_size = 400
our_sample = sf.sample(sample_size, with_replacement=False)

# %%
our_sample.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Organization Group</th> <th>Department</th> <th>Job Family</th> <th>Job</th> <th>Salary</th> <th>Overtime</th> <th>Benefits</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Human Welfare & Neighborhood Development</td> <td>Human Services          </td> <td>Management            </td> <td>Dep Dir III          </td> <td>200644</td> <td>0       </td> <td>77105   </td> <td>277749            </td>
#         </tr>
#         <tr>
#             <td>General Administration & Finance        </td> <td>Department of Technology</td> <td>Information Systems   </td> <td>IS Engineer-Principal</td> <td>66792 </td> <td>0       </td> <td>25178   </td> <td>91970             </td>
#         </tr>
#         <tr>
#             <td>Public Protection                       </td> <td>Fire Department         </td> <td>Fire Services         </td> <td>Firefighter          </td> <td>128793</td> <td>19463   </td> <td>45035   </td> <td>193290            </td>
#         </tr>
#         <tr>
#             <td>Public Works, Transportation & Commerce </td> <td>Airport Commission      </td> <td>Housekeeping & Laundry</td> <td>Custodian            </td> <td>28943 </td> <td>1751    </td> <td>16854   </td> <td>47549             </td>
#         </tr>
#         <tr>
#             <td>Public Protection                       </td> <td>Fire Department         </td> <td>Fire Services         </td> <td>Firefighter          </td> <td>106302</td> <td>22409   </td> <td>39766   </td> <td>168477            </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (395 rows omitted)</p>

# %%
# sampling 한 것의 중간값은 달라짐 > 이걸 할때마다 얼마나 달라지는 가를 구하고자 함!
percentile(50, our_sample.column('Total Compensation') )
# Out:
# 138458.0

# %% [markdown]
# But in the real world we won't be able to keep going back to the population. How to generate a new random sample *without going back to the population?*

# %% [markdown]
# # **Bootstrap**
#
# Sample randomly
#  - from the original sample
#  - with replacement
#  - the same number of times as the original sample size

# %%
# Default behavior of tbl.sample:
# at random with replacement,
# the same number of times as rows of tbl
# 원래 population은 모르지만 그것과 sample이 비슷할 것이야라고 가정한다.
bootstrap_sample = our_sample.sample() # replace하며 행의 개수만큼 뽑은 상태
bootstrap_sample.hist('Total Compensation', bins=sf_bins)

# %% [markdown]
# ## **Bootstrap Sample Median**
# This is one estimate of the population median.

# %%
percentile(50, bootstrap_sample.column('Total Compensation'))
# Out:
# 139716.0

# %%
def one_bootstrap_median():
    # draw the bootstrap sample
    resample = our_sample.sample() # 리샘플링하며 with replacement
    # return the median total compensation in the bootstrap sample
    return percentile(50, resample.column('Total Compensation'))

# %%
one_bootstrap_median()
# Out:
# 127727.0

# %%
# Generate the medians of 1000 bootstrap samples
# 1000번 돌며 resampling 한것들의 median 값들을 저장한다.
num_repetitions = 1000
bstrap_medians = make_array()
for i in np.arange(num_repetitions):
    bstrap_medians = np.append(bstrap_medians, one_bootstrap_median())

# %%
resampled_medians = Table().with_column(
    'Bootstrap Sample Median', bstrap_medians)
median_bins=np.arange(120000, 160000, 2000)
resampled_medians.hist(bins = median_bins)

# Plotting parameters; you can ignore this code
# population에서 sampling된 것의 median
parameter_green = '#32CD32'
plots.ylim(-0.000005, 0.00014)
plots.scatter(pop_median, 0, color=parameter_green, s=40, zorder=2)
plots.title('Bootstrap Medians and the Parameter (Green Dot)');

# %%
# 95%에 해당하는 구간을 출력
left = percentile(2.5, bstrap_medians)
right = percentile(97.5, bstrap_medians)

make_array(left, right)
# Out:
# array([ 124817.,  141082.])

# %%
resampled_medians.hist(bins=median_bins)

# Plotting parameters; you can ignore his code
plots.ylim(-0.000005, 0.00014)
plots.plot(make_array(left, right), make_array(0, 0), color='yellow', lw=3, zorder=1)
plots.scatter(pop_median, 0, color=parameter_green, s=40, zorder=2);

# %%
# Parameter: Median total compensation in the population
def median_comp(t):
    return percentile(50, t.column('Total Compensation'))

median_comp(sf)
# Out:
# 135747.0

# %% [markdown]
# ## **Bootstrap Estimates of the Parameter (Pretend it is Unknown)**

# %%
# Collect one random sample from the population
sample_size = 100
our_sample = sf.sample(sample_size, with_replacement=False)

# Generate the medians of 1000 bootstrap samples
num_repretitions = 1000
bstrap_medians = make_array()
for i in np.arange(num_repretitions):
    # Resample the same number of rows, with replacement
    resample = our_sample.sample()
    bstrap_medians = np.append(bstrap_medians,
                                median_comp(resample))

# Find the middle 95% of medians; that's a confidence Interval
left = percentile(2.5, bstrap_medians)
right = percentile(97.5, bstrap_medians)

make_array(left, right)
# Out:
# array([ 116742.,  142160.])

# %%
# 얘를 다시 정의해야할 거 같음..ㅎ
def confidence_interval_95(sample_size):
    our_sample = sf.sample(sample_size, with_replacement=False)

  # Generate the medians of 1000 bootstrap samples
    num_repretitions = 1000
    bstrap_medians = make_array()
    for i in np.arange(num_repretitions):
    # Resample the same number of rows, with replacement
      resample = our_sample.sample()
      bstrap_medians = np.append(bstrap_medians,
                                median_comp(resample))

# Find the middle 95% of medians; that's a confidence Interval
    left = percentile(2.5, bstrap_medians)
    right = percentile(97.5, bstrap_medians)

    return make_array(left, right)

# %% [markdown]
# ## **Confidence Interval for Unknown Population Mean**

# %%
intervals = Table(['k', 'lower', 'upper', 'sample_size'])

for n in [100, 400]:
    for k in np.arange(intervals.num_rows, intervals.num_rows + 20):
        interval = confidence_interval_95(n)
        intervals = intervals.with_row([
            k, interval.item(0), interval.item(1), n
        ])

intervals.show(4)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>k</th> <th>lower</th> <th>upper</th> <th>sample_size</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0   </td> <td>123483</td> <td>151315</td> <td>100        </td>
#         </tr>
#         <tr>
#             <td>1   </td> <td>121516</td> <td>160169</td> <td>100        </td>
#         </tr>
#         <tr>
#             <td>2   </td> <td>115628</td> <td>145761</td> <td>100        </td>
#         </tr>
#         <tr>
#             <td>3   </td> <td>104029</td> <td>144821</td> <td>100        </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (36 rows omitted)</p>

# %%
intervals.scatter('lower', 'k', group='sample_size')
truth = percentile(50, sf.column('Total Compensation')) # 정답지
plots.plot((truth, truth), (0, intervals.num_rows), color='green', lw=3)
plots.xticks([120000, 1500000])
for row in intervals.rows:
    if row.item('lower') > truth or row.item('upper') < truth:
        color = 'red'
    else:
        color = 'blue'
    plots.plot((row.item('lower'), row.item('upper')),
               (row.item('k'), row.item('k')),
               color, lw=2)

# %%
intervals = Table(['k', 'lower', 'upper', 'sample_size'])

for n in [2, 4, 8, 16]:
    for k in np.arange(intervals.num_rows, intervals.num_rows + 20):
        interval = confidence_interval_95(n)
        intervals = intervals.with_row([
            k, interval.item(0), interval.item(1), n
        ])

intervals.show(4)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>k</th> <th>lower</th> <th>upper</th> <th>sample_size</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0   </td> <td>28887 </td> <td>70126 </td> <td>2          </td>
#         </tr>
#         <tr>
#             <td>1   </td> <td>25958 </td> <td>94199 </td> <td>2          </td>
#         </tr>
#         <tr>
#             <td>2   </td> <td>93787 </td> <td>97348 </td> <td>2          </td>
#         </tr>
#         <tr>
#             <td>3   </td> <td>121926</td> <td>331004</td> <td>2          </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (76 rows omitted)</p>

# %%
intervals.scatter('lower', 'k', group='sample_size')
truth = percentile(50, sf.column('Total Compensation'))
plots.plot((truth, truth), (0, intervals.num_rows), color='green', lw=3)
plots.xticks([120000, 1500000])
for row in intervals.rows:
    if row.item('lower') > truth or row.item('upper') < truth:
        color = 'red'
    else:
        color = 'blue'
    plots.plot((row.item('lower'), row.item('upper')),
               (row.item('k'), row.item('k')),
               color, lw=2)

# %% [markdown]
# --> Lecture Note로 돌아감

# %% [markdown]
# ## **Confidence Interval for Unknown Population Mean**

# %%
# Random sample of mother-newborn pairs
births = Table.read_table('baby.csv')
births.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Birth Weight</th> <th>Gestational Days</th> <th>Maternal Age</th> <th>Maternal Height</th> <th>Maternal Pregnancy Weight</th> <th>Maternal Smoker</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>120         </td> <td>284             </td> <td>27          </td> <td>62             </td> <td>100                      </td> <td>False          </td>
#         </tr>
#         <tr>
#             <td>113         </td> <td>282             </td> <td>33          </td> <td>64             </td> <td>135                      </td> <td>False          </td>
#         </tr>
#         <tr>
#             <td>128         </td> <td>279             </td> <td>28          </td> <td>64             </td> <td>115                      </td> <td>True           </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1171 rows omitted)</p>

# %%
births.hist('Maternal Age')

# %%
# Average age of mothers in the sample
np.average(births.column('Maternal Age'))
# Out:
# 27.228279386712096

# %% [markdown]
# ### Question
# What is the average age of the mothers in the population?

# %%
def one_bootstrap_mean():
    resample = births.sample()
    return np.average(resample.column('Maternal Age'))

# %%
# Generate means from 3000 bootstrap samples
num_repetitions = 3000
bstrap_means = make_array()
for i in np.arange(num_repetitions):
    bstrap_means = np.append(bstrap_means, one_bootstrap_mean())

# %% [markdown]
# ### Bootstrap Percentile Method for Confidence Interval
#
# The interval of estimates is the "middle 95%" of the bootstrap estimates.
#
# This is called a *95% confidence interval* for the mean age in the population.

# %%
# Get the endpoints of the 95% confidence interval
left = percentile(2.5, bstrap_means)
right = percentile(97.5, bstrap_means)

make_array(left, right)

# %%
resampled_means = Table().with_columns(
    'Bootstrap Sample Mean', bstrap_means
)
resampled_means.hist(bins=15)
plots.plot([left, right], [0, 0], color='yellow', lw=8);

# %%
births.hist('Maternal Age')
plots.plot([left, right], [0, 0], color='yellow', lw=8);
